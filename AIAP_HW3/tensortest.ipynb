# %%
import tensorflow
# Out:
# ---------------------------------------------------------------------------
# AlreadyExistsError                        Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import tensorflow
#
# File ~\.conda\envs\KAMP\lib\site-packages\tensorflow\__init__.py:478
#     473 # Do an eager load for Keras' code so that any function/method that needs to
#     474 # happen at load time will trigger, eg registration of optimizers in the
#     475 # SavedModel registry.
#     476 # See b/196254385 for more details.
#     477 try:
# --> 478   importlib.import_module("keras.optimizers")
#     479 except (ImportError, AttributeError):
#     480   pass
#
# File ~\.conda\envs\KAMP\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\.conda\envs\KAMP\lib\site-packages\keras\__init__.py:20
# ...
